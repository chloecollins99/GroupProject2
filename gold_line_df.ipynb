# %%
import pandas as pd

# %%
gold = "../GroupProject2-master/gold_line.csv"
gold_line = pd.read_csv(gold)
gold_line.head()
# Out:
#                       location  address  city  zip_code       lat       lon  \
# 0               LaSalle Street      NaN   NaN       NaN  35.26298 -80.85470
# 1                   Russell Av      NaN   NaN       NaN  35.25703 -80.85558
# 2        Booker Avenue/Oaklawn      NaN   NaN       NaN  35.25380 -80.85597
# 3                French Street      NaN   NaN       NaN  35.24685 -80.85679
# 4  Johnson C. Smith University      NaN   NaN       NaN  35.24173 -80.85869
#
#   category  state  info
# 0     Gold    NaN   NaN
# 1     Gold    NaN   NaN
# 2     Gold    NaN   NaN
# 3     Gold    NaN   NaN
# 4     Gold    NaN   NaN

# %%
clean_df = gold_line.drop(['address', 'city', 'zip_code', 'state', 'info'], axis=1)
clean_df
# Out:
#                               location       lat       lon category
# 0                       LaSalle Street  35.26298 -80.85470     Gold
# 1                           Russell Av  35.25703 -80.85558     Gold
# 2                Booker Avenue/Oaklawn  35.25380 -80.85597     Gold
# 3                        French Street  35.24685 -80.85679     Gold
# 4          Johnson C. Smith University  35.24173 -80.85869     Gold
# 5                         Bruns Avenue  35.24026 -80.85843     Gold
# 6                   Wesley Heights Way  35.23710 -80.85866     Gold
# 7                      Johnson & Wales  35.23380 -80.85113     Gold
# 8            Charlotte Gateway Station  35.23131 -80.84773     Gold
# 9                          Mint Street  35.22942 -80.84566     Gold
# 10                        Tryon Street  35.22720 -80.84307     Gold
# 11                   Hawthorne and 5th  35.23285 -80.81108     Gold
# 12                       Veterans Park  35.21974 -80.80409     Gold
# ...

# %%
clean_df.to_html('gold_df')
