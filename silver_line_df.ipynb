# %%
import pandas as pd
import numpy as np

# %%
silver = "../GroupProject2-master/silver_line.csv"
silver_line = pd.read_csv(silver)
silver_line.head()
# Out:
#                        location  address  city  zip_code        lat  \
# 0                   CPCC Levine      NaN   NaN       NaN  35.103324
# 1           Matthews Sportsplex      NaN   NaN       NaN  35.112094
# 2  Matthews Downtown / Hospital      NaN   NaN       NaN  35.119506
# 3     Matthews Township Parkway      NaN   NaN       NaN  35.126350
# 4          Sardis Rd / Galleria      NaN   NaN       NaN  35.136414
#
#          lon category  state  info
# 0 -80.697421   Silver    NaN   NaN
# 1 -80.705134   Silver    NaN   NaN
# 2 -80.716414   Silver    NaN   NaN
# 3 -80.728251   Silver    NaN   NaN
# 4 -80.737754   Silver    NaN   NaN

# %%
clean_df = silver_line.drop(['address', 'city', 'zip_code', 'state', 'info'], axis=1)
clean_df
# Out:
#                          location        lat        lon category
# 0                     CPCC Levine  35.103324 -80.697421   Silver
# 1             Matthews Sportsplex  35.112094 -80.705134   Silver
# 2    Matthews Downtown / Hospital  35.119506 -80.716414   Silver
# 3       Matthews Township Parkway  35.126350 -80.728251   Silver
# 4            Sardis Rd / Galleria  35.136414 -80.737754   Silver
# 5                 Village Lake Dr  35.158047 -80.748703   Silver
# 6                   Conference Dr  35.181798 -80.755695   Silver
# 7                 Sharon Amity Rd  35.193655 -80.766284   Silver
# 8                   Amity Gardens  35.200974 -80.779285   Silver
# 9                Coliseum / Ovens  35.203716 -80.796081   Silver
# 10                 Morningside Dr  35.213283 -80.803436   Silver
# 11                      Pecan Ave  35.218073 -80.814799   Silver
# 12                    Central Ave  35.220877 -80.826314   Silver
# ...

# %%
clean_df.to_html('silver_df')
