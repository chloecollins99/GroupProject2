# %%
import pandas as pd

# %%
red = "../GroupProject2-master/red_line.csv"
red_line = pd.read_csv(red)
red_line.head()
# Out:
#                     location                                      address  \
# 0  Charlotte Gateway Station  West Trade Street Charlotte, North Carolina
# 1                     Derita                      Derita Rd, Charlotte NC
# 2                     Harris                W.T Harris Blvd, Charlotte NC
# 3                  Eastfield                Arthur Davis Rd, Charlotte NC
# 4                  Hambright                Hambright Rd, Huntersville NC
#
#    city  zip_code       lat       lon category  state  info
# 0   NaN     28202  35.23131 -80.84773      Red    NaN     1
# 1   NaN     28269  35.30110 -80.80568      Red    NaN     2
# 2   NaN     28269  35.33518 -80.82504      Red    NaN     3
# 3   NaN     28269  35.35358 -80.82208      Red    NaN     4
# 4   NaN     28078  35.37755 -80.83361      Red    NaN     5

# %%
clean_df = red_line.drop(['city', 'state'], axis=1)
clean_df
# Out:
#                     location                                      address  \
# 0  Charlotte Gateway Station  West Trade Street Charlotte, North Carolina
# 1                     Derita                      Derita Rd, Charlotte NC
# 2                     Harris                W.T Harris Blvd, Charlotte NC
# 3                  Eastfield                Arthur Davis Rd, Charlotte NC
# 4                  Hambright                Hambright Rd, Huntersville NC
# 5               Huntersville                  Huntersville North Carolina
# 6                   Sam Furr                Sam Furr Rd, Huntersville, NC
# 7                  Cornelius                                Cornelius, NC
# 8                   Davidson                                 Davidson, NC
# 9               Mount Mourne                Mecklenburg, Hwy, Davidson NC
#
#    zip_code       lat       lon category  info
# 0     28202  35.23131 -80.84773      Red     1
# 1     28269  35.30110 -80.80568      Red     2
# ...

# %%
clean_df.to_html('red_df')
