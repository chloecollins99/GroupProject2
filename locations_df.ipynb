# %%
import pandas as pd

# %%
locations = "../GroupProject2-master/locations.csv"
locations_df = pd.read_csv(locations)
locations_df.head()
# Out:
#                      location                        address          city  \
# 0  Erwin-Oehler House Acreage  14401 Huntersville-Concord Rd  Huntersville
# 1       McLaughlin-Bost House                  415 W John St      Matthews
# 2    Park Avenue Mill Village                   411 Park Ave     Pineville
# 3        Hamilton Jones House                201 Cherokee Rd     Charlotte
# 4  Pineville Commercial Block                    318 Main St     Pineville
#
#    zip_code        lat        lon  category state                     info
# 0       NaN  35.416819 -80.804446  historic    NC                     Land
# 1       NaN  35.118552 -80.727050  historic    NC  19th Century Vernacular
# 2       NaN  35.081570 -80.893615  historic    NC             Mill Village
# 3       NaN  35.201652 -80.821235  historic    NC            Tudor Revival
# 4       NaN  35.085868 -80.890676  historic    NC               Commercial

# %%
clean_df = locations_df.drop(['zip_code'], axis=1)
clean_df
# Out:
#                                               location  \
# 0                           Erwin-Oehler House Acreage
# 1                                McLaughlin-Bost House
# 2                             Park Avenue Mill Village
# 3                                 Hamilton Jones House
# 4                           Pineville Commercial Block
# 5                                     W.D. Beaty House
# 6                                    John Hunter House
# 7                                   Mint Museum of Art
# 8                                 Randolph Scott House
# 9                                         Hoskins Mill
# 10                               Big Rock Rock Shelter
# 11                               Tompkins Machine Shop
# 12            McCausland Building-Thacker's Restaurant
# 13                      Providence Presbyterian Church
# 14                                Jones-Garibald House
# 15                              Torrance House & Store
# ...

# %%
clean_df.to_html('locations_df')
