# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
from config import gkey
lhp_pd = pd.read_csv("blue_line.csv")
lhp_pd.head()
# Out:
#    Unnamed: 0                               location           address  city  \
# 0           0                                 Carson  218 E. Carson Bv   NaN
# 1           1  Charlotte Transportation Center/Arena   303 E. Trade St   NaN
# 2           2                       I-485/South Blvd     9508 South Bv   NaN
# 3           3                       Sharon Road West     8815 Crump Rd   NaN
# 4           4                               Arrowood   7717 England St   NaN
#
#    zip_code        lat        lon category  state  info
# 0     28203  35.218905 -80.851835     Blue    NaN   NaN
# 1     28202  35.225510 -80.840870     Blue    NaN   NaN
# 2     28273  35.106879 -80.882237     Blue    NaN   NaN
# 3     28134  35.119992 -80.882237     Blue    NaN   NaN
# 4     28273  35.134202 -80.876641     Blue    NaN   NaN

# %%
clean_df = lhp_pd.drop(['city', 'state', 'info'], axis=1)
clean_df
# Out:
#     Unnamed: 0                               location                address  \
# 0            0                                 Carson       218 E. Carson Bv
# 1            1  Charlotte Transportation Center/Arena        303 E. Trade St
# 2            2                       I-485/South Blvd          9508 South Bv
# 3            3                       Sharon Road West          8815 Crump Rd
# 4            4                               Arrowood        7717 England St
# 5            5                               Archdale          6230 South Bv
# 6            6                                 Tyvola  5703 Old Pineville Rd
# 7            7                               Woodlawn  4756 Old Pineville Rd
# 8            8                             Scaleybark          3750 South Bv
# 9            9                               New Bern        129 New Bern St
# 10          10                              East/West         1821 Camden St
# ...

# %%
clean_df.to_html('blue_df')
